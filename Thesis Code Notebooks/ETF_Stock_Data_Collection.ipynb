# %%
# !pip install yfinance --quiet

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# fix_yahoo_finance is used to fetch data
import yfinance as yf
yf.pdr_override()

# %%
market1 = '^GSPC'

start = '1950-01-03'
end = '2023-12-31'

# Read data
dataset1 = yf.download(market1,start,end)

dataset1.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#              Open   High    Low  Close  Adj Close   Volume
# Date
# 1950-01-03  16.66  16.66  16.66  16.66      16.66  1260000
# 1950-01-04  16.85  16.85  16.85  16.85      16.85  1890000
# 1950-01-05  16.93  16.93  16.93  16.93      16.93  2550000
# 1950-01-06  16.98  16.98  16.98  16.98      16.98  2010000
# 1950-01-09  17.08  17.08  17.08  17.08      17.08  2520000

# %%
from pylab import rcParams

rcParams['figure.figsize'] = 10, 3

plt.plot(dataset1['Close'], color='blue', linewidth=0.7)
plt.grid()
plt.legend(['Price'])
plt.title('S&P since 1950 - Price')
plt.show()

# %%
market1 = '^GSPC'

start = '2019-01-01'
end = '2024-02-25'

# Read data
dataset = yf.download(market1,start,end)

dataset.to_csv('Index_Stock_Data/^GSPC_new.csv')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
market2 = '^N225'

start = '1965-01-01'

dataset2 = yf.download(market2,start,end)

dataset2.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1965-01-05  1257.719971  1257.719971  1257.719971  1257.719971  1257.719971
# 1965-01-06  1263.989990  1263.989990  1263.989990  1263.989990  1263.989990
# 1965-01-07  1274.270020  1274.270020  1274.270020  1274.270020  1274.270020
# 1965-01-08  1286.430054  1286.430054  1286.430054  1286.430054  1286.430054
# 1965-01-12  1288.540039  1288.540039  1288.540039  1288.540039  1288.540039
#
#             Volume
# Date
# 1965-01-05       0
# 1965-01-06       0
# 1965-01-07       0
# 1965-01-08       0
# 1965-01-12       0

# %%
from pylab import rcParams

rcParams['figure.figsize'] = 10, 3

plt.plot(dataset2['Close'], color='blue', linewidth=0.7)
plt.grid()
plt.legend(['Price'])
plt.title('N225 since 1965 - Price')
plt.show()

# %%
market3 = '000001.SS'

start = '1996-01-01'

dataset3 = yf.download(market3,start,end)

dataset3.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1997-07-02  1255.909058  1261.571045  1147.331055  1199.061035  1199.061035
# 1997-07-03  1194.676025  1194.676025  1149.939941  1150.623047  1150.623047
# 1997-07-04  1138.921021  1163.249023  1124.776001  1159.342041  1159.342041
# 1997-07-07  1161.707031  1163.447021  1085.572021  1096.818970  1096.818970
# 1997-07-08  1092.798950  1115.432983  1066.043945  1109.666016  1109.666016
#
#             Volume
# Date
# 1997-07-02       0
# 1997-07-03       0
# 1997-07-04       0
# 1997-07-07       0
# 1997-07-08       0

# %%
from pylab import rcParams

rcParams['figure.figsize'] = 10, 3

plt.plot(dataset3['Close'], color='blue', linewidth=0.7)
plt.grid()
plt.legend(['Price'])
plt.title('SSE since 1996 - Price')
plt.show()

# %%
market4 = '^HSI'

start = '1987-01-01'

dataset4 = yf.download(market4,start,end)

dataset4.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1987-01-02  2540.100098  2540.100098  2540.100098  2540.100098  2540.100098
# 1987-01-05  2552.399902  2552.399902  2552.399902  2552.399902  2552.399902
# 1987-01-06  2583.899902  2583.899902  2583.899902  2583.899902  2583.899902
# 1987-01-07  2607.100098  2607.100098  2607.100098  2607.100098  2607.100098
# 1987-01-08  2603.300049  2603.300049  2603.300049  2603.300049  2603.300049
#
#             Volume
# Date
# 1987-01-02       0
# 1987-01-05       0
# 1987-01-06       0
# 1987-01-07       0
# 1987-01-08       0

# %%
from pylab import rcParams

rcParams['figure.figsize'] = 10, 3

plt.plot(dataset4['Close'], color='blue', linewidth=0.7)
plt.grid()
plt.legend(['Price'])
plt.title('HSI since 1987 - Price')
plt.show()

# %%
market5 = '^BSESN'

start = '1997-07-01'

dataset5 = yf.download(market5,start,end)

dataset5.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1997-07-01  4263.109863  4301.770020  4247.660156  4300.859863  4300.859863
# 1997-07-02  4302.959961  4395.310059  4295.399902  4333.899902  4333.899902
# 1997-07-03  4335.790039  4393.290039  4299.970215  4323.459961  4323.459961
# 1997-07-04  4332.700195  4347.589844  4300.580078  4323.819824  4323.819824
# 1997-07-07  4326.810059  4391.009766  4289.490234  4291.450195  4291.450195
#
#             Volume
# Date
# 1997-07-01       0
# 1997-07-02       0
# 1997-07-03       0
# 1997-07-04       0
# 1997-07-07       0

# %%
from pylab import rcParams

rcParams['figure.figsize'] = 10, 3

plt.plot(dataset5['Close'], color='blue', linewidth=0.7)
plt.grid()
plt.legend(['Price'])
plt.title('BSESN since 2018 - Price')
plt.show()

# %%
market6 = '^SSMI'

start = '1990-01-01'

dataset6 = yf.download(market6,start,end)

dataset6.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1990-11-09  1378.900024  1389.000000  1375.300049  1387.099976  1387.099976
# 1990-11-12  1388.099976  1408.099976  1388.099976  1407.500000  1407.500000
# 1990-11-13  1412.199951  1429.400024  1411.400024  1415.199951  1415.199951
# 1990-11-14  1413.599976  1413.599976  1402.099976  1410.300049  1410.300049
# 1990-11-15  1410.599976  1416.699951  1405.099976  1405.699951  1405.699951
#
#             Volume
# Date
# 1990-11-09       0
# 1990-11-12       0
# 1990-11-13       0
# 1990-11-14       0
# 1990-11-15       0

# %%
from pylab import rcParams

rcParams['figure.figsize'] = 10, 3

plt.plot(dataset6['Close'], color='blue', linewidth=0.7)
plt.grid()
plt.legend(['Price'])
plt.title('SMI since 1990 - Price')
plt.show()

# %%
market7 = '^BVSP'

start = '2002-01-01'

dataset7 = yf.download(market7,start,end)

dataset7.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                Open     High      Low    Close  Adj Close  Volume
# Date
# 2002-01-02  13586.0  13902.0  13571.0  13872.0    13872.0       0
# 2002-01-03  14125.0  14286.0  14121.0  14265.0    14265.0       0
# 2002-01-04  14250.0  14358.0  14103.0  14332.0    14332.0       0
# 2002-01-07  14327.0  14413.0  14273.0  14379.0    14379.0       0
# 2002-01-08  14385.0  14385.0  14099.0  14168.0    14168.0       0

# %%
from pylab import rcParams

rcParams['figure.figsize'] = 10, 3

plt.plot(dataset7['Close'], color='blue', linewidth=0.7)
plt.grid()
plt.legend(['Price'])
plt.title('BVSP since 2002 - Price')
plt.show()

# %%
dataset1.to_csv('Index_Stock_Data/^GSPC.csv')
dataset2.to_csv('Index_Stock_Data/^N225.csv')
dataset3.to_csv('Index_Stock_Data/SSE.csv')
dataset4.to_csv('Index_Stock_Data/^HSI.csv')
dataset5.to_csv('Index_Stock_Data/^BSESN.csv')
dataset6.to_csv('Index_Stock_Data/^SSMI.csv')
dataset7.to_csv('Index_Stock_Data/^BVSP.csv')

# %%
# !zip -r /content/file.zip /content/Index_Stock_Data
# Out:
#   adding: content/Index_Stock_Data/ (stored 0%)
#   adding: content/Index_Stock_Data/SSE.csv (deflated 76%)
#   adding: content/Index_Stock_Data/^BVSP.csv (deflated 70%)
#   adding: content/Index_Stock_Data/^BSESN.csv (deflated 75%)
#   adding: content/Index_Stock_Data/^GSPC_new.csv (deflated 77%)
#   adding: content/Index_Stock_Data/.ipynb_checkpoints/ (stored 0%)
#   adding: content/Index_Stock_Data/^SSMI.csv (deflated 77%)
#   adding: content/Index_Stock_Data/^GSPC.csv (deflated 83%)
#   adding: content/Index_Stock_Data/^N225.csv (deflated 82%)
#   adding: content/Index_Stock_Data/^HSI.csv (deflated 76%)

# %%
from google.colab import files
files.download("/content/file.zip")
